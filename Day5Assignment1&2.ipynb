# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeepProject/ICTTestRepo/blob/main/Day5Assignment1%262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Bank Account Manager
#a. Simulate a bank account with deposit, withdrawal, and balance
#enquiry operations
#b. Use variables and data types to store account information
#c. Implement conditional statements to check for sufficient balance
#before withdrawal
#d. Use functions to perform deposit, withdrawal, and balance inquiry
#operations.
#flag 1 : deposit
#flag 2 : withdrawal
#flag 3 : Balance Enquiry
ac_Balance= 1000
def account_Manage(acNo,flag,amount):
    account_No = 2252
    global ac_Balance

    if flag ==1 and account_No==acNo:
        ac_Balance=ac_Balance+amount
        #print(ac_Balance)
    elif flag==2 and account_No==acNo:
        if ac_Balance>1000:
            ac_Balance=ac_Balance-amount
            #print(ac_Balance)
        else:
            print("Insufficient Balance for the withdrawal. Try again!")
    elif flag==3 and account_No==acNo:
        return ac_Balance
    else:
        print("Error")
    return(ac_Balance)

# %%
print("1 : deposit, 2: Withdrawal, 3: Balance Check")
trans_Type= int(input("Transaction Type :"))
if trans_Type==3:
  trans_AcNo = input("Account Number :")
  #trans_Amount = input("Amount :")
  trans_Amount=0
  Bank_Balance=account_Manage(float(trans_AcNo),int(trans_Type),float(trans_Amount))
  if(trans_Type==1 or trans_Type==2):
    print(f"Account Balance is : {Bank_Balance}")
  elif trans_Type==3:
    print(f"Account Balance is : {Bank_Balance}")
  else:
    print("Something Went Wrong!")
else:
  print("Try for another transaction!")
# Out:
# 1 : deposit, 2: Withdrawal, 3: Balance Check
# Transaction Type :3
# Account Number :2252
# Account Balance is : 5000.0

# %%
print("1 : deposit, 2: Withdrawal, 3: Balance Check")
trans_Type= int(input("Transaction Type :"))
trans_AcNo = input("Account Number :")
trans_Amount = input("Amount :")
Bank_Balance=account_Manage(float(trans_AcNo),int(trans_Type),float(trans_Amount))
if(trans_Type==1 or trans_Type==2):
    print(f"Account Balance is : {Bank_Balance}")
elif trans_Type==3:
   print(f"Account Balance is : {Bank_Balance}")
else:
  print("Something Went Wrong!")
# Out:
# 1 : deposit, 2: Withdrawal, 3: Balance Check
# Transaction Type :1
# Account Number :2252
# Amount :2000
# 5000.0
# Account Balance is : 5000.0

# %%
print("1 : deposit, 2: Withdrawal, 3: Balance Check")
trans_Type= int(input("Transaction Type :"))
trans_AcNo = input("Account Number :")
trans_Amount = input("Amount :")
Bank_Balance=account_Manage(float(trans_AcNo),int(trans_Type),float(trans_Amount))
if(trans_Type==1 or trans_Type==2):
    print(f"Account Balance is : {Bank_Balance}")
elif trans_Type==3:
   print(f"Account Balance is : {Bank_Balance}")
else:
  print("Something Went Wrong!")
# Out:
# 1 : deposit, 2: Withdrawal, 3: Balance Check
# Transaction Type :2
# Account Number :2252
# Amount :1000
# Account Balance is : 4000.0

# %%
#Assigment 2:
#Weather Data Analyzer
#a. Analyze weather data (temperature, humidity, etc.) for a given region
#b. Use variables and data types to store weather data
#c. Implement conditional statements to determine weather conditions
#(sunny, rainy, etc.)
#d. Use functions to calculate average temperature and humidity, and print
#results

#Tdp~T-(100-RH)/5
#Tdp - T : is between  - <=2 : Rainy, foggy, or heavily overcast
#Tdp - T : is between >2 - <=5 : Cloudy
#Tdp - T : is between >5 - <=10 : Partialy Cloudy
#Tdp - T : is >10 : Sunny
def weather_Analyzer(country):
    weather_data={"India":[25,90],"China":[30,40],"UK":[23,60]}
    country_data=weather_data[country]
    temp=country_data[0]
    humid=country_data[1]
    dew_point=temp-(100-humid)/5
    dew_Point_Difference = temp- dew_point
    if dew_Point_Difference <=2:
        return 1
    elif dew_Point_Difference >2 and dew_Point_Difference <=5:
        return 2
    elif dew_Point_Difference >5 and dew_Point_Difference <=10:
        return 3
    else:
        return 4


region= input("Enter the Region : ")
flag=weather_Analyzer(region)
if flag==1:
    print("Rainy, foggy, or heavily overcast")
elif flag==2:
    print("Cloudy")
elif flag==3:
    print("Partialy Cloudy")
else:
    print("Sunny")

def average_Calculation():
    weather_data={"India":[25,90],"China":[30,40],"UK":[23,60]}
    temp = [items_list[0] for items_list in weather_data.values() if items_list]
    #print(temp)
    humid = [items_list[1] for items_list in weather_data.values() if items_list]
    #print(humid)
# Calculate the sum of the list elements
    total_sum_temp = sum(temp)
    total_sum_humid = sum(humid)
# Calculate the number of elements in the list
    data_Count_Temp = len(temp)
    data_Count_Humid = len(humid)

# Calculate the average of temperature
    if data_Count_Temp > 0:
        average = total_sum_temp / data_Count_Temp
        print(f"The list is: {temp}")
        print(f"The average temperature is: {round(average)}")
    else:
        print("Cannot calculate average for an empty list.")

# Calculate the average of humidity
    if data_Count_Temp > 0:
        average = total_sum_humid/ data_Count_Humid
        print(f"The list is: {humid}")
        print(f"The average humidity is: {round(average)}")
    else:
        print("Cannot calculate average for an empty list.")
average_Calculation()
# Out:
# Enter the Region : China
# Sunny
# The list is: [25, 30, 23]
# The average temperature is: 26
# The list is: [90, 40, 60]
# The average humidity is: 63
